# %%
# 02_insight_generation.ipynb

import pandas as pd
import google.generativeai as genai
import os

# Load cleaned data
df = pd.read_csv("../data/cleaned_sales.csv")

# API setup (Set your Gemini API key here)
os.environ["GOOGLE_API_KEY"] = "AIzaSyBVPKd8aUdijfZGu-KUjdDTAVk0WOPSr0M"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Summarize data into a prompt
summary_prompt = f"""
Given the following business sales data:

{df[['Date', 'Product', 'Region', 'Units Sold', 'Revenue']].head(50).to_string(index=False)}

Please provide:
- Top-performing products
- Any dips or anomalies in revenue
- Regional performance trends
- Overall business insights
"""

model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content(summary_prompt)

print("AI Insights:")
print(response.text)
# Out:
# AI Insights:
# Okay, let's analyze the sales data you provided to identify top-performing products, revenue anomalies, regional trends, and overall business insights.
#
# **1. Top-Performing Products:**
#
# To determine this, we need to aggregate revenue and units sold by product across all regions and timeframes.
#
# | Product  | Total Units Sold | Total Revenue |
# |----------|------------------|---------------|
# | Widget A | 570              | \$30,624.95   |
# | Widget B | 511              | \$28,316.85   |
# | Gadget X | 470              | \$24,804.60   |
# | Gadget Y | 165              | \$7,531.69    |
#
# **Analysis:**
#
# *   **Widget A** is the clear revenue leader.
# *   **Widget B** is also a strong performer, closely behind Widget A.
# *   **Gadget X** is doing respectably, significantly behind the Widget category, but still a substantial contributor.
# *   **Gadget Y** is the lowest performer in terms of both unit sales and revenue, needing further attention.
#
# ...
